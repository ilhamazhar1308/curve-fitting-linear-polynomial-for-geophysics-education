# %% [markdown]
# <a href="https://colab.research.google.com/github/ilhamazhar1308/curve-fitting-linear-polynomial-for-geophysics-education/blob/main/Curve_Fitting_Using_Linear_and_Polynomial_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**LINEAR REGRESSION**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Input data
n = int(input('Enter the number of data points to be input: '))
s = []
5
# Input depth data
x = []
for i in range(n):
  X = float(input('Enter depth data number-%d: ' %i))
  x.append(X)

# Input temperature data
y = []
for i in range(n):
  Y = float(input('Enter temperature data number-%d: ' %i))
  y.append(Y)

print('Data X : ', X)
print('Data Y : ', Y)

xsum = 0
ysum = 0
x2sum = 0
jumlah = 0

for i in range(n):
  xsum = xsum + x[i]
  ysum = ysum + y[i]
  x2sum = x2sum + (x[i]**2)
  jumlah = jumlah + x[i]*y[i]

a = (n*jumlah - xsum*ysum)/(x2sum*n - xsum*xsum)
b = (x2sum*ysum - xsum*jumlah)/(x2sum*n - xsum*xsum)
Y = np.zeros(n)
for i in range(n):
  Y[i] = a*x[i] + b

print("The Linear Fitting is : ", Y)
print("The linear fitting function is : T =", a, "Z +", b)
plt.plot(x, y, 'o', x, Y)
plt.title('Temperature Variation with Depth')
plt.xlabel('Depth (m)')
plt.ylabel('Temperature (Celsius)')
plt.show()
# Out:
# Enter the number of data points to be input: 5
# Enter depth data number-0: 6
# Enter depth data number-1: 4
# Enter depth data number-2: 3
# Enter depth data number-3: 2
# Enter depth data number-4: 7
# Enter temperature data number-0: 8
# Enter temperature data number-1: 2
# Enter temperature data number-2: 2
# Enter temperature data number-3: 4
# Enter temperature data number-4: 4
# Data X :  7.0
# Data Y :  4.0
# The Linear Fitting is :  [4.93023256 3.76744186 3.18604651 2.60465116 5.51162791]
# The linear fitting function is : T = 0.5813953488372093 Z + 1.441860465116279

# %% [markdown]
# #**POLYNOMIAL REGRESSION**

# %%
import numpy as np
import matplotlib.pyplot as plt

n = int(input('Enter the number of data points to be input: '))
x = []
for i in range(n):
    data_x = float(input('Enter the value of x-axis number-%d: ' %i))
    x.append(data_x)

y = []
for i in range(n):
    data_y = float(input('Enter the value of y-axis number-%d: ' %i))
    y.append(data_y)

print('Data X:', x)
print('Data Y:', y)
polinom = int(input('Enter the polynomial degree to be used: '))

z = np.polyfit(x, y, polinom)
f = np.poly1d(z)
print('The fitted equation for degree %d: \n' %polinom, f)
x_pol = np.linspace(x[0], x[-1], 50)
y_pol = f(x_pol)

plt.plot(x, y, 'o', x_pol, y_pol)
plt.title('Depth (m)')
plt.xlabel('Depth (m)')
plt.ylabel('Temperature Variation with Depth')
plt.show()
# Out:
# Masukan jumlah data yang ingin diinput:8
# Masukkan Nilai dari Axis-x ke0:5
# Masukkan Nilai dari Axis-x ke1:8
# Masukkan Nilai dari Axis-x ke2:14
# Masukkan Nilai dari Axis-x ke3:21
# Masukkan Nilai dari Axis-x ke4:30
# Masukkan Nilai dari Axis-x ke5:36
# Masukkan Nilai dari Axis-x ke6:45
# Masukkan Nilai dari Axis-x ke7:60
# Masukkan Nilai dari Axis-y ke0:20.099
# Masukkan Nilai dari Axis-y ke1:22.099
# Masukkan Nilai dari Axis-y ke2:25.099
# Masukkan Nilai dari Axis-y ke3:32.099
# Masukkan Nilai dari Axis-y ke4:41.099
# Masukkan Nilai dari Axis-y ke5:48.099
# Masukkan Nilai dari Axis-y ke6:63.099
# Masukkan Nilai dari Axis-y ke7:74.099
# Data X: [5.0, 8.0, 14.0, 21.0, 30.0, 36.0, 45.0, 60.0]
# Data Y: [20.099, 22.099, 25.099, 32.099, 41.099, 48.099, 63.099, 74.099]
# Masukan Derajat Polinom Yang InginDingunakan: 7
# persamaan yang fit untuk derajat 7:
#             7             6             5            4           3
# ...
